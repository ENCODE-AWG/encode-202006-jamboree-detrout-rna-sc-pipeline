# %%
import pandas
from pathlib import Path
from pprint import pprint
import re
import sys
from collections import Counter, namedtuple

# %%
EC = str(Path("~/proj/encoded_client").expanduser())
if EC not in sys.path:
    sys.path.append(EC)
from encoded_client.encoded import ENCODED

# %%
server = ENCODED("www.encodeproject.org")

# %%
query = server.search_jsonld(type="Experiment", assay_title="scRNA-seq", limit="all", **{"lab.title":  "Ali Mortazavi, UCI"})
print(len(query["@graph"]))
# Out:
# 140

# %%
query["@graph"][0]["replicates"][0]["library"]["biosample"]
# Out:
# {'organism': {'scientific_name': 'Mus musculus'},
#  'age_display': '4 days',
#  'life_stage': 'unknown',
#  'accession': 'ENCBS937WPV',
#  'subcellular_fraction_term_name': 'nucleus'}

# %%
metadata = []
prefix = "ali-mortazavi:"
for row in query["@graph"]:
    experiment = server.get_json(row["@id"])
    experiment_aliases = experiment["aliases"]
    assert len(experiment_aliases) == 1
    experiment_aliases = experiment_aliases[0][len(prefix):]

    read_count = 0
    for f in experiment["files"]:
        if f["file_type"] == "fastq":
            read_count = f["read_count"]
            break

    for replicate in experiment["replicates"]:
        #replicate = server.get_json(replicate_stub["@id"])
        library = replicate["library"]
        library_id = library["@id"]
        library_accession = library["accession"]
        library_aliases = library["aliases"]
        assert len(library_aliases) == 1
        library_aliases = library_aliases[0][len(prefix):]
        biosample = library["biosample"]
        biosample_accession = biosample["accession"]
        biosample_id = biosample["@id"]
        biosample_aliases = biosample["aliases"]
        subcellular_fraction = biosample.get("subcellular_fraction_term_name", "")
        assert len(biosample_aliases) == 1
        biosample_aliases = biosample_aliases[0][len(prefix):]

        metadata.append({
            "experiment": row["accession"],
            "experiment_aliases": experiment_aliases,
            "library": library_accession,
            "library_alias": library_aliases,
            "read_count": read_count,
            "biosample": biosample_accession,
            "biosample_alias": biosample_aliases,
            "subcellular_fraction": subcellular_fraction,
            "biosample_description": biosample["description"],
        })

metadata = pandas.DataFrame(metadata)
metadata
# Out:
#       experiment                        experiment_aliases      library  \
# 0    ENCSR193PLQ                  exp_sr_P4_female_adrenal  ENCLB098ERF
# 1    ENCSR193PLQ                  exp_sr_P4_female_adrenal  ENCLB082IOS
# 2    ENCSR962DRE                 exp_sr_P25_female_adrenal  ENCLB523MJQ
# 3    ENCSR962DRE                 exp_sr_P25_female_adrenal  ENCLB697JVD
# 4    ENCSR331DYV                  exp_sr_P2mo_male_adrenal  ENCLB469XPD
# ..           ...                                       ...          ...
# 269  ENCSR477EIC  exp_sr_P2mo_female_gastrocnemius_shallow  ENCLB983QCI
# 270  ENCSR062ICV              exp_sr_P4_female_cortex_deep  ENCLB401ZUR
# 271  ENCSR062ICV              exp_sr_P4_female_cortex_deep  ENCLB440ABL
# 272  ENCSR877UAI               exp_sr_P4_male_adrenal_deep  ENCLB343SXS
# 273  ENCSR877UAI               exp_sr_P4_male_adrenal_deep  ENCLB747XAC
#
#                                       library_alias  read_count    biosample  \
# 0                    library_sr_P4_female_adrenal_1     7575705  ENCBS937WPV
# 1                    library_sr_P4_female_adrenal_2     7575705  ENCBS083TAX
# 2                   library_sr_P25_female_adrenal_1    15650091  ENCBS575HZP
# 3                   library_sr_P25_female_adrenal_2    15650091  ENCBS875QSI
# 4                    library_sr_P2mo_male_adrenal_1     8817023  ENCBS033LDD
# ..                                              ...         ...          ...
# 269  library_sr_P2mo_female_gastrocnemius_2_shallow    13411124  ENCBS124VMY
# 270              library_sr_P4_female_cortex_1_deep     2799625  ENCBS075VEC
# 271              library_sr_P4_female_cortex_2_deep     2799625  ENCBS431VFB
# 272               library_sr_P4_male_adrenal_2_deep     4701514  ENCBS314KWD
# 273               library_sr_P4_male_adrenal_1_deep     4701514  ENCBS015YYI
#
#                            biosample_alias subcellular_fraction  \
# 0            biosample_P4_female_adrenal_1              nucleus
# 1            biosample_P4_female_adrenal_2              nucleus
# 2           biosample_P25_female_adrenal_1              nucleus
# 3           biosample_P25_female_adrenal_2              nucleus
# 4            biosample_P2mo_male_adrenal_1              nucleus
# ..                                     ...                  ...
# 269  biosample_P2mo_female_gastrocnemius_2              nucleus
# 270           biosample_P4_female_cortex_1              nucleus
# 271           biosample_P4_female_cortex_2              nucleus
# 272            biosample_P4_male_adrenal_2              nucleus
# 273            biosample_P4_male_adrenal_1              nucleus
#
#                      biosample_description
# 0            B6Cast F1 P4 female adrenal 7
# 1            B6Cast F1 P4 female adrenal 8
# 2           B6Cast F1 P25 female adrenal 7
# 3           B6Cast F1 P25 female adrenal 8
# 4            B6Cast F1 P2mo male adrenal 7
# ..                                     ...
# 269  B6Cast F1 P2mo female gastrocnemius 8
# 270           B6Cast F1 P4 female cortex 7
# 271           B6Cast F1 P4 female cortex 8
# 272            B6Cast F1 P4 male adrenal 8
# 273            B6Cast F1 P4 male adrenal 7
#
# [274 rows x 9 columns]

# %%
metadata = metadata.sort_values("experiment_aliases")

# %%
c2c12 = metadata[metadata["experiment_aliases"].apply(lambda x: "c2c12" in x)]
c2c12
# Out:
#       experiment experiment_aliases      library              library_alias  \
# 266  ENCSR388EIN  sr_1k_c2c12_sc_mb  ENCLB952MZJ  library_sr_1k_c2c12_sc_mb
# 263  ENCSR877NAX  sr_1k_c2c12_sn_mb  ENCLB514RKT  library_sr_1k_c2c12_sn_mb
# 104  ENCSR572SMD  sr_1k_c2c12_sn_mt  ENCLB273ZWE  library_sr_1k_c2c12_sn_mt
# 144  ENCSR503QZJ  sr_9k_c2c12_sc_mb  ENCLB129LMS  library_sr_9k_c2c12_sc_mb
# 267  ENCSR452OYH  sr_9k_c2c12_sn_mb  ENCLB294FBZ  library_sr_9k_c2c12_sn_mb
# 111  ENCSR109DAN  sr_9k_c2c12_sn_mt  ENCLB527JDU  library_sr_9k_c2c12_sn_mt
#
#      read_count    biosample        biosample_alias subcellular_fraction  \
# 266     8527474  ENCBS521YWL  biosample_c2c12_sc_mb
# 263    11081223  ENCBS431NOZ  biosample_c2c12_sn_mb              nucleus
# 104    11335807  ENCBS978ZNQ  biosample_c2c12_sn_mt              nucleus
# 144    38274516  ENCBS521YWL  biosample_c2c12_sc_mb
# 267    44213518  ENCBS431NOZ  biosample_c2c12_sn_mb              nucleus
# 111    23120573  ENCBS978ZNQ  biosample_c2c12_sn_mt              nucleus
#
#               biosample_description
# 266     C2C12 single-cell myoblasts
# 263  C2C12 single-nucleus myoblasts
# 104   C2C12 single-nucleus myotubes
# 144     C2C12 single-cell myoblasts
# 267  C2C12 single-nucleus myoblasts
# 111   C2C12 single-nucleus myotubes

# %%
[(x["accession"], x["read_count"]) for x in experiment["files"] if x["file_type"] == "fastq"]
# Out:
# [('ENCFF496PNG', 4701514),
#  ('ENCFF795FHL', 2330829),
#  ('ENCFF077TDR', 4701514),
#  ('ENCFF389CIY', 2330829)]

# %%
metadata.to_excel("uci-sc-experiment-decoder.xlsx")
c2c12.to_excel("c2c12/c2c12-encode-portal.xlsx")

# %%
experiment["assay_term_name"]
# Out:
# 'single-cell RNA sequencing assay'

# %%
server.get_json("ENCSR877NAX")["assay_term_name"]
# Out:
# 'single-cell RNA sequencing assay'
