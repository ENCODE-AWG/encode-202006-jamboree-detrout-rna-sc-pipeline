# %%
import requests
import pandas
import scipy
import numpy
import scanpy
from io import StringIO

# %%
req = requests.get('https://www.encodeproject.org/files/ENCFF809UII/@@download/ENCFF809UII.tsv')
stream = StringIO(req.text)
ovary = pandas.read_csv(stream, sep='\t')

# %%
ovary
# Out:
#                                                 target_id  length  eff_length  \
# 0       ENST00000456328.2|ENSG00000223972.5|OTTHUMG000...    1657   1403.7900
# 1       ENST00000450305.2|ENSG00000223972.5|OTTHUMG000...     632    381.3590
# 2       ENST00000488147.1|ENSG00000227232.5|OTTHUMG000...    1351   1097.7900
# 3       ENST00000619216.1|ENSG00000278267.1|-|-|MIR685...      68     31.9048
# 4       ENST00000473358.1|ENSG00000243485.5|OTTHUMG000...     712    459.4180
# ...                                                   ...     ...         ...
# 206786                                         ERCC-00165     872    618.8100
# 206787                                         ERCC-00168    1024    770.7930
# 206788                                         ERCC-00170    1023    769.7930
# 206789                                         ERCC-00171     505    266.4220
# 206790                                            phiX174    5386   5132.7900
#
# ...
