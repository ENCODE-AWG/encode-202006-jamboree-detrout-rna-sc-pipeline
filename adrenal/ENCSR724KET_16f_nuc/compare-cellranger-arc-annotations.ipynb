# %% [markdown]
# # Introduction

# %% [markdown]
# I should double check what's been removed in the 10x minimal annotation set.

# %%
import scipy
import pandas
import scanpy
import numpy
from pathlib import Path
from matplotlib import pyplot
import os
import sys
from collections import Counter
from xopen import xopen

import upsetplot

# %%
WRS = str(Path("~/proj/long-rna-seq-condor/").expanduser())

if WRS not in sys.path:
    sys.path.append(WRS)

from woldrnaseq import gff2table

# %%
tenx_root = Path("~/proj/illumina/refdata-cellranger-arc-GRCh38-2020-A-2.0.0").expanduser()
tenx_parser = gff2table.GFFParser()
with xopen(tenx_root / "genes" / "genes.gtf.gz", "rt") as instream:
    tenx_parser.read_gff(instream)
# Out:
# gtf.shape (2765969, 9)

# %%
tenx_parser.gtf
# Out:
#          chromosome   source        type   start    stop  score  strand  \
# 0              chr1   HAVANA        gene   29554   31109    NaN       1
# 1              chr1   HAVANA  transcript   29554   31097    NaN       1
# 2              chr1   HAVANA        exon   29554   30039    NaN       1
# 3              chr1   HAVANA        exon   30564   30667    NaN       1
# 4              chr1   HAVANA        exon   30976   31097    NaN       1
# ...             ...      ...         ...     ...     ...    ...     ...
# 2765964  KI270734.1  ENSEMBL         CDS  138483  138667    NaN      -1
# 2765965  KI270734.1  ENSEMBL  stop_codon  138480  138482    NaN      -1
# 2765966  KI270734.1  ENSEMBL         UTR  161689  161852    NaN      -1
# 2765967  KI270734.1  ENSEMBL         UTR  161587  161626    NaN      -1
# 2765968  KI270734.1  ENSEMBL         UTR  138082  138482    NaN      -1
#
#          frame          gene_id gene_version  ... transcript_type  \
# 0          NaN  ENSG00000243485            5  ...             NaN
# 1          NaN  ENSG00000243485            5  ...          lncRNA
# 2          NaN  ENSG00000243485            5  ...          lncRNA
# 3          NaN  ENSG00000243485            5  ...          lncRNA
# 4          NaN  ENSG00000243485            5  ...          lncRNA
# ...        ...              ...          ...  ...             ...
# 2765964    2.0  ENSG00000277196            4  ...  protein_coding
# 2765965    0.0  ENSG00000277196            4  ...  protein_coding
# 2765966    NaN  ENSG00000277196            4  ...  protein_coding
# 2765967    NaN  ENSG00000277196            4  ...  protein_coding
# 2765968    NaN  ENSG00000277196            4  ...  protein_coding
#
#          transcript_name  transcript_support_level     havana_transcript  \
# 0                    NaN                       NaN                   NaN
# 1        MIR1302-2HG-202                         5  OTTHUMT00000002840.1
# 2        MIR1302-2HG-202                         5  OTTHUMT00000002840.1
# 3        MIR1302-2HG-202                         5  OTTHUMT00000002840.1
# 4        MIR1302-2HG-202                         5  OTTHUMT00000002840.1
# ...                  ...                       ...                   ...
# 2765964   AC007325.2-201                         1                   NaN
# 2765965   AC007325.2-201                         1                   NaN
# 2765966   AC007325.2-201                         1                   NaN
# 2765967   AC007325.2-201                         1                   NaN
# 2765968   AC007325.2-201                         1                   NaN
#
#         exon_number          exon_id exon_version         protein_id ccdsid  \
# 0               NaN              NaN          NaN                NaN    NaN
# 1               NaN              NaN          NaN                NaN    NaN
# 2               1.0  ENSE00001947070            1                NaN    NaN
# 3               2.0  ENSE00001922571            1                NaN    NaN
# 4               3.0  ENSE00001827679            1                NaN    NaN
# ...             ...              ...          ...                ...    ...
# 2765964        15.0  ENSE00003753010            1  ENSP00000481127.1    NaN
# 2765965        15.0  ENSE00003753010            1  ENSP00000481127.1    NaN
# 2765966         1.0  ENSE00003746084            1  ENSP00000481127.1    NaN
# 2765967         2.0  ENSE00003719550            1  ENSP00000481127.1    NaN
# 2765968        15.0  ENSE00003753010            1  ENSP00000481127.1    NaN
#
#          ont
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 2765964  NaN
# 2765965  NaN
# 2765966  NaN
# 2765967  NaN
# 2765968  NaN
#
# [2765969 rows x 28 columns]

# %%
v29_genome_dir = Path("~/proj/genome").expanduser()
v29 = v29_genome_dir / "GRCh38-V29-male-2.7.8a" / "GRCh38-V29-male-2.7.8a.h5"
store = pandas.HDFStore(v29, "r")
try:
    genes = store.select("/gtf", columns=["gene_id", "transcript_id", "gene_type", "transcript_type"], where=["type==gene"])
    gtf = store['/gtf']
finally:
    store.close()

# %%
genes['gene_base'] = genes['gene_id'].apply(lambda x: x.split('.')[0])

# %%
genes_types_included = pandas.Series(Counter(tenx_parser.gtf[tenx_parser.gtf['type'] == 'gene']['gene_type'])).to_frame('count').sort_values(by="count", ascending=False)
genes_types_included
# Out:
#                  count
# protein_coding   19394
# lncRNA           16562
# IG_V_pseudogene    188
# IG_V_gene          144
# TR_V_gene          106
# TR_J_gene           79
# IG_D_gene           37
# TR_V_pseudogene     33
# IG_J_gene           18
# IG_C_gene           14
# IG_C_pseudogene      9
# TR_C_gene            6
# TR_D_gene            4
# TR_J_pseudogene      4
# IG_J_pseudogene      3

# %%
tenx_parser.gtf[tenx_parser.gtf['gene_id'] == 'ENSG00000267749'][['gene_id', 'gene_type', 'transcript_type']]
# Out:
#                  gene_id gene_type transcript_type
# 2362196  ENSG00000267749    lncRNA             NaN
# 2362197  ENSG00000267749    lncRNA          lncRNA
# 2362198  ENSG00000267749    lncRNA          lncRNA

# %%
genes_types_available = pandas.Series(Counter(genes['gene_type'])).to_frame('count').sort_values(by="count", ascending=False)
genes_types_available
# Out:
#                                     count
# protein_coding                      19969
# processed_pseudogene                10198
# lincRNA                              7635
# antisense                            5587
# unprocessed_pseudogene               2649
# misc_RNA                             2222
# snRNA                                1909
# miRNA                                1881
# TEC                                  1060
# snoRNA                                943
# sense_intronic                        895
# transcribed_unprocessed_pseudogene    886
# processed_transcript                  601
# rRNA_pseudogene                       500
# transcribed_processed_pseudogene      481
# IG_V_pseudogene                       188
# sense_overlapping                     180
# IG_V_gene                             144
# transcribed_unitary_pseudogene        124
# TR_V_gene                             106
# unitary_pseudogene                     95
# TR_J_gene                              79
# bidirectional_promoter_lncRNA          73
# rRNA                                   58
# scaRNA                                 49
# polymorphic_pseudogene                 41
# IG_D_gene                              37
# TR_V_pseudogene                        33
# 3prime_overlapping_ncRNA               32
# Mt_tRNA                                22
# pseudogene                             22
# IG_J_gene                              18
# IG_C_gene                              14
# IG_C_pseudogene                         9
# ribozyme                                8
# TR_C_gene                               6
# sRNA                                    5
# TR_D_gene                               4
# TR_J_pseudogene                         4
# IG_J_pseudogene                         3
# translated_processed_pseudogene         2
# non_coding                              2
# Mt_rRNA                                 2
# vaultRNA                                1
# scRNA                                   1
# macro_lncRNA                            1
# IG_pseudogene                           1

# %%
target_dir = Path("~/proj/encode-202006-jamboree-detrout-rna-sc-pipeline/genome/GRCh38-V29_minimal-male").expanduser()

# %%
trna_types =  pandas.Series(Counter(gtf[gtf['type'] == 'tRNA']['gene_type'])).to_frame('count').sort_values(by="count", ascending=False)
trna_types
# Out:
#              count
# Pseudo_tRNA    114
# Ala_tRNA        48
# Leu_tRNA        40
# Asn_tRNA        38
# Val_tRNA        36
# Gln_tRNA        33
# Lys_tRNA        33
# Gly_tRNA        32
# Cys_tRNA        30
# Ser_tRNA        28
# Arg_tRNA        28
# Glu_tRNA        26
# Ile_tRNA        23
# Thr_tRNA        22
# Met_tRNA        22
# Pro_tRNA        21
# Asp_tRNA        19
# Tyr_tRNA        15
# Phe_tRNA        12
# His_tRNA        11
# Trp_tRNA         9
# Undet_tRNA       3
# Sup_tRNA         3
# SeC(e)_tRNA      2
# SeC_tRNA         1

# %%
desired_types = set(genes_types_included.index)
desired_types
# Out:
# {'IG_C_gene',
#  'IG_C_pseudogene',
#  'IG_D_gene',
#  'IG_J_gene',
#  'IG_J_pseudogene',
#  'IG_V_gene',
#  'IG_V_pseudogene',
#  'TR_C_gene',
#  'TR_D_gene',
#  'TR_J_gene',
#  'TR_J_pseudogene',
#  'TR_V_gene',
#  'TR_V_pseudogene',
#  'lncRNA',
#  'protein_coding'}

# %%
desired_types.add('lincRNA')
desired_types
# Out:
# {'IG_C_gene',
#  'IG_C_pseudogene',
#  'IG_D_gene',
#  'IG_J_gene',
#  'IG_J_pseudogene',
#  'IG_V_gene',
#  'IG_V_pseudogene',
#  'TR_C_gene',
#  'TR_D_gene',
#  'TR_J_gene',
#  'TR_J_pseudogene',
#  'TR_V_gene',
#  'TR_V_pseudogene',
#  'lincRNA',
#  'lncRNA',
#  'protein_coding'}

# %%
pandas.Series(Counter(gtf[gtf['type'] == 'tRNA']['gene_type'])).to_frame('count').sort_values(by="count", ascending=False)
# Out:
#              count
# Pseudo_tRNA    114
# Ala_tRNA        48
# Leu_tRNA        40
# Asn_tRNA        38
# Val_tRNA        36
# Gln_tRNA        33
# Lys_tRNA        33
# Gly_tRNA        32
# Cys_tRNA        30
# Ser_tRNA        28
# Arg_tRNA        28
# Glu_tRNA        26
# Ile_tRNA        23
# Thr_tRNA        22
# Met_tRNA        22
# Pro_tRNA        21
# Asp_tRNA        19
# Tyr_tRNA        15
# Phe_tRNA        12
# His_tRNA        11
# Trp_tRNA         9
# Undet_tRNA       3
# Sup_tRNA         3
# SeC(e)_tRNA      2
# SeC_tRNA         1

# %%
desired_genes = set(genes[genes['gene_type'].isin(desired_types)]['gene_id'])

# %%
set(genes[genes['gene_type'].isin(desired_types)]['gene_type'])
# Out:
# {'IG_C_gene',
#  'IG_C_pseudogene',
#  'IG_D_gene',
#  'IG_J_gene',
#  'IG_J_pseudogene',
#  'IG_V_gene',
#  'IG_V_pseudogene',
#  'TR_C_gene',
#  'TR_D_gene',
#  'TR_J_gene',
#  'TR_J_pseudogene',
#  'TR_V_gene',
#  'TR_V_pseudogene',
#  'lincRNA',
#  'protein_coding'}

# %%
target_gtf = target_dir / "minimal.V29.gtf"
with open(target_gtf, "wt") as outstream:
    # write out regular gtf records
    for i, row in gtf.iterrows():
        if row['gene_id'] in desired_genes:
            outstream.write(gff2table.format_gtf_record(row))
            outstream.write(os.linesep)

# %%
filtered_parser = gff2table.GFFParser()
filtered_parser.read_gff(target_gtf)
filtered_parser.gtf.shape
# Out:
# gtf.shape (2568904, 9)
# (2568904, 24)

# %%
desired_genes
# Out:
# {'ENSG00000183032.11',
#  'ENSG00000172113.9',
#  'ENSG00000230773.7',
#  'ENSG00000144306.14',
#  'ENSG00000114841.17',
#  'ENSG00000129467.13',
#  'ENSG00000275969.2',
#  'ENSG00000173575.20',
#  'ENSG00000079308.18',
#  'ENSG00000126759.13',
#  'ENSG00000121749.15',
#  'ENSG00000256742.1',
#  'ENSG00000173214.5',
#  'ENSG00000223430.1',
#  'ENSG00000272297.2',
#  'ENSG00000119718.10',
#  'ENSG00000167615.16',
#  'ENSG00000211650.2',
#  'ENSG00000234956.6',
#  'ENSG00000257366.1',
#  'ENSG00000285079.1',
#  'ENSG00000123352.17',
#  'ENSG00000204682.5',
#  'ENSG00000204814.5',
#  'ENSG00000109625.18',
#  'ENSG00000092096.16',
#  'ENSG00000154027.18',
#  'ENSG00000143951.15',
#  'ENSG00000143867.6',
#  'ENSG00000116095.10',
#  'ENSG00000095383.19',
#  'ENSG00000242553.1',
#  'ENSG00000214686.5',
#  'ENSG00000243566.6',
#  'ENSG00000205089.7',
#  'ENSG00000205693.3',
#  'ENSG00000106327.12',
#  'ENSG00000279151.1',
#  'ENSG00000006459.10',
#  'ENSG00000233081.1',
#  'ENSG00000169683.7',
#  'ENSG00000125895.5',
#  'ENSG00000142632.16',
#  'ENSG00000176472.10',
#  'ENSG00000198899.2',
#  'ENSG00000203883.6',
#  'ENSG00000165995.19',
#  'ENSG00000257654.1',
#  'ENSG00000178279.3',
#  'ENSG00000167555.13',
#  'ENSG00000101236.16',
#  'ENSG00000154342.5',
#  'ENSG00000183475.12',
#  'ENSG00000144278.14',
#  'ENSG00000151116.16',
#  'ENSG00000260259.1',
#  'ENSG00000233415.1',
#  'ENSG00000010610.9',
#  'ENSG00000273342.1',
#  'ENSG00000213923.11',
#  'ENSG00000170523.3',
#  'ENSG00000172578.11',
#  'ENSG00000142552.7',
#  'ENSG00000186185.13',
#  'ENSG00000285655.1',
#  'ENSG00000071909.18',
#  'ENSG00000100867.14',
#  'ENSG00000105298.13',
#  'ENSG00000224132.2',
#  'ENSG00000113430.9',
#  'ENSG00000122008.15',
#  'ENSG00000141349.8',
#  'ENSG00000231683.6',
#  'ENSG00000148672.8',
#  'ENSG00000224440.1',
#  'ENSG00000197629.5',
#  'ENSG00000166794.4',
#  'ENSG00000100211.10',
#  'ENSG00000146425.10',
#  'ENSG00000115204.14',
#  'ENSG00000281591.1',
#  'ENSG00000056972.18',
#  'ENSG00000259200.1',
#  'ENSG00000285886.1',
#  'ENSG00000163958.13',
#  'ENSG00000138813.9',
#  'ENSG00000279797.1',
#  'ENSG00000058600.15',
#  'ENSG00000181026.14',
#  'ENSG00000268912.1',
#  'ENSG00000232886.1',
#  'ENSG00000172667.10',
#  'ENSG00000101938.14',
#  'ENSG00000125414.18',
#  'ENSG00000100599.15',
#  'ENSG00000144381.16',
#  'ENSG00000283988.1',
#  'ENSG00000272221.1',
#  'ENSG00000172339.9',
#  'ENSG00000197124.11',
#  'ENSG00000105443.14',
#  'ENSG00000266065.1',
#  'ENSG00000223872.1',
#  'ENSG00000108551.4',
#  'ENSG00000273956.1',
#  'ENSG00000272688.1',
#  'ENSG00000159708.17',
#  'ENSG00000212659.1',
#  'ENSG00000211941.3',
#  'ENSG00000161677.11',
#  'ENSG00000169020.9',
#  'ENSG00000254819.1',
#  'ENSG00000257185.1',
#  'ENSG00000104341.16',
#  'ENSG00000183090.5',
#  'ENSG00000106018.13',
#  'ENSG00000137843.11',
#  'ENSG00000262663.1',
#  'ENSG00000232543.2',
#  'ENSG00000258433.1',
#  'ENSG00000269855.2',
#  'ENSG00000102158.19',
#  'ENSG00000118200.14',
#  'ENSG00000111012.9',
#  'ENSG00000282317.1',
#  'ENSG00000233056.2',
#  'ENSG00000224470.7',
#  'ENSG00000185338.5',
#  'ENSG00000141574.7',
#  'ENSG00000164304.15',
#  'ENSG00000187210.13',
#  'ENSG00000274818.1',
#  'ENSG00000204110.6',
#  'ENSG00000077152.10',
#  'ENSG00000283597.2',
#  'ENSG00000203722.7',
#  'ENSG00000225948.2',
#  'ENSG00000131089.15',
#  'ENSG00000157870.15',
#  'ENSG00000112592.13',
#  'ENSG00000171049.8',
#  'ENSG00000258178.1',
#  'ENSG00000262267.5',
#  'ENSG00000264695.1',
#  'ENSG00000225857.5',
#  'ENSG00000152056.16',
#  'ENSG00000215784.5',
#  'ENSG00000198133.8',
#  'ENSG00000103254.9',
#  'ENSG00000228777.1',
#  'ENSG00000156802.12',
#  'ENSG00000113716.12',
#  'ENSG00000008256.15',
#  'ENSG00000082153.17',
#  'ENSG00000182183.14',
#  'ENSG00000257474.5',
#  'ENSG00000070915.9',
#  'ENSG00000186280.6',
#  'ENSG00000185515.14',
#  'ENSG00000067113.16',
#  'ENSG00000168032.9',
#  'ENSG00000276529.1',
#  'ENSG00000261811.1',
#  'ENSG00000182938.5',
#  'ENSG00000126432.13',
#  'ENSG00000258517.1',
#  'ENSG00000122406.13',
#  'ENSG00000148835.10',
#  'ENSG00000204947.8',
#  'ENSG00000254266.5',
#  'ENSG00000230394.1',
#  'ENSG00000282787.1',
#  'ENSG00000197894.10',
#  'ENSG00000205809.9',
#  'ENSG00000183718.5',
#  'ENSG00000197451.11',
#  'ENSG00000020181.17',
#  'ENSG00000112195.8',
#  'ENSG00000267740.5',
#  'ENSG00000283073.1',
#  'ENSG00000164305.18',
#  'ENSG00000187554.12',
#  'ENSG00000176393.10',
#  'ENSG00000148229.12',
#  'ENSG00000236720.1',
#  'ENSG00000272426.1',
#  'ENSG00000231626.1',
#  'ENSG00000147206.16',
#  'ENSG00000164695.4',
#  'ENSG00000162430.16',
#  'ENSG00000154240.16',
#  'ENSG00000128000.15',
#  'ENSG00000198785.4',
#  'ENSG00000167232.13',
#  'ENSG00000178175.11',
#  'ENSG00000114204.14',
#  'ENSG00000155714.13',
#  'ENSG00000235584.2',
#  'ENSG00000254573.1',
#  'ENSG00000143641.9',
#  'ENSG00000164107.8',
#  'ENSG00000254396.1',
#  'ENSG00000113722.16',
#  'ENSG00000153551.13',
#  'ENSG00000135317.12',
#  'ENSG00000174667.4',
#  'ENSG00000196475.5',
#  'ENSG00000211918.1',
#  'ENSG00000135720.12',
#  'ENSG00000131437.15',
#  'ENSG00000183310.3',
#  'ENSG00000119121.21',
#  'ENSG00000138107.12',
#  'ENSG00000237563.1',
#  'ENSG00000182613.2',
#  'ENSG00000166111.9',
#  'ENSG00000054938.15',
#  'ENSG00000257563.1',
#  'ENSG00000248491.5',
#  'ENSG00000111752.10',
#  'ENSG00000117151.12',
#  'ENSG00000229205.3',
#  'ENSG00000259383.1',
#  'ENSG00000139998.15',
#  'ENSG00000187626.8',
#  'ENSG00000189377.8',
#  'ENSG00000168036.17',
#  'ENSG00000112941.13',
#  'ENSG00000134419.15',
#  'ENSG00000251615.3',
#  'ENSG00000259438.1',
#  'ENSG00000173083.14',
#  'ENSG00000145029.13',
#  'ENSG00000072133.10',
#  'ENSG00000253634.2',
#  'ENSG00000234147.1',
#  'ENSG00000163751.3',
#  'ENSG00000163412.12',
#  'ENSG00000263041.1',
#  'ENSG00000225620.1',
#  'ENSG00000165006.13',
#  'ENSG00000092199.17',
#  'ENSG00000164508.4',
#  'ENSG00000230631.1',
#  'ENSG00000172650.13',
#  'ENSG00000273919.1',
#  'ENSG00000151292.17',
#  'ENSG00000186834.3',
#  'ENSG00000010539.11',
#  'ENSG00000205670.10',
#  'ENSG00000226741.1',
#  'ENSG00000005981.12',
#  'ENSG00000132155.11',
#  'ENSG00000225684.3',
#  'ENSG00000108669.16',
#  'ENSG00000227486.1',
#  'ENSG00000231925.11',
#  'ENSG00000284373.1',
#  'ENSG00000188549.12',
#  'ENSG00000160145.15',
#  'ENSG00000116151.13',
#  'ENSG00000183287.14',
#  'ENSG00000175395.15',
#  'ENSG00000115548.16',
#  'ENSG00000175697.10',
#  'ENSG00000225258.1',
#  'ENSG00000238291.1',
#  'ENSG00000273230.1',
#  'ENSG00000112812.15',
#  'ENSG00000068885.14',
#  'ENSG00000204595.1',
#  'ENSG00000102996.4',
#  'ENSG00000204193.10',
#  'ENSG00000229962.1',
#  'ENSG00000253484.1',
#  'ENSG00000204962.5',
#  'ENSG00000159147.17',
#  'ENSG00000187714.6',
#  'ENSG00000170615.14',
#  'ENSG00000137720.7',
#  'ENSG00000116679.15',
#  'ENSG00000223387.6',
#  'ENSG00000063438.16',
#  'ENSG00000271734.1',
#  'ENSG00000172183.14',
#  'ENSG00000185664.14',
#  'ENSG00000224271.5',
#  'ENSG00000271824.1',
#  'ENSG00000273136.6',
#  'ENSG00000117751.17',
#  'ENSG00000177954.12',
#  'ENSG00000260737.5',
#  'ENSG00000255427.1',
#  'ENSG00000177468.6',
#  'ENSG00000129749.3',
#  'ENSG00000254975.1',
#  'ENSG00000132780.16',
#  'ENSG00000016602.9',
#  'ENSG00000120738.7',
#  'ENSG00000204952.2',
#  'ENSG00000132664.11',
#  'ENSG00000253889.1',
#  'ENSG00000270302.1',
#  'ENSG00000167004.12',
#  'ENSG00000088782.4',
#  'ENSG00000277587.1',
#  'ENSG00000122188.12',
#  'ENSG00000038274.16',
#  'ENSG00000166816.14',
#  'ENSG00000272259.5',
#  'ENSG00000100227.17',
#  'ENSG00000172053.17',
#  'ENSG00000166987.14',
#  'ENSG00000172269.18',
#  'ENSG00000250742.2',
#  'ENSG00000211952.3',
#  'ENSG00000254415.3',
#  'ENSG00000167580.7',
#  'ENSG00000147130.14',
#  'ENSG00000076344.15',
#  'ENSG00000185250.15',
#  'ENSG00000261166.1',
#  'ENSG00000284797.1',
#  'ENSG00000107731.12',
#  'ENSG00000154124.4',
#  'ENSG00000152818.18',
#  'ENSG00000138162.18',
#  'ENSG00000227342.1',
#  'ENSG00000138709.18',
#  'ENSG00000256972.1',
#  'ENSG00000149948.13',
#  'ENSG00000231274.5',
#  'ENSG00000204449.3',
#  'ENSG00000164220.6',
#  'ENSG00000182255.6',
#  'ENSG00000005189.19',
#  'ENSG00000169727.12',
#  'ENSG00000089248.6',
#  'ENSG00000284989.1',
#  'ENSG00000122971.8',
#  'ENSG00000105136.20',
#  'ENSG00000116176.6',
#  'ENSG00000117569.18',
#  'ENSG00000178718.6',
#  'ENSG00000254343.2',
#  'ENSG00000196284.15',
#  'ENSG00000049883.14',
#  'ENSG00000258779.7',
#  'ENSG00000120616.15',
#  'ENSG00000269035.1',
#  'ENSG00000158023.9',
#  'ENSG00000102524.11',
#  'ENSG00000273218.1',
#  'ENSG00000177558.3',
#  'ENSG00000197721.16',
#  'ENSG00000266967.6',
#  'ENSG00000175354.19',
#  'ENSG00000260861.6',
#  'ENSG00000185291.11_PAR_Y',
#  'ENSG00000185163.9',
#  'ENSG00000186393.5',
#  'ENSG00000130224.14',
#  'ENSG00000146054.17',
#  'ENSG00000196628.16',
#  'ENSG00000013364.18',
#  'ENSG00000182447.4',
#  'ENSG00000271830.1',
#  'ENSG00000075413.17',
#  'ENSG00000189401.2',
#  'ENSG00000174501.14',
#  'ENSG00000156869.13',
#  'ENSG00000275409.1',
#  'ENSG00000271449.7',
#  'ENSG00000255580.1',
#  'ENSG00000274251.1',
#  'ENSG00000177757.2',
#  'ENSG00000248538.7',
#  'ENSG00000096063.15',
#  'ENSG00000260850.2',
#  'ENSG00000212864.3',
#  'ENSG00000282246.1',
#  'ENSG00000106003.12',
#  'ENSG00000140987.19',
#  'ENSG00000261400.1',
#  'ENSG00000280095.1',
#  'ENSG00000187122.16',
#  'ENSG00000265303.1',
#  'ENSG00000120899.17',
#  'ENSG00000235661.3',
#  'ENSG00000133657.15',
#  'ENSG00000254469.7',
#  'ENSG00000223714.1',
#  'ENSG00000215277.8',
#  'ENSG00000285523.1',
#  'ENSG00000147854.16',
#  'ENSG00000109511.11',
#  'ENSG00000260052.1',
#  'ENSG00000156970.12',
#  'ENSG00000284696.1',
#  'ENSG00000261000.1',
#  'ENSG00000226237.1',
#  'ENSG00000258931.1',
#  'ENSG00000153339.13',
#  'ENSG00000160199.14',
#  'ENSG00000167515.10',
#  'ENSG00000198574.5',
#  'ENSG00000285929.1',
#  'ENSG00000189252.4',
#  'ENSG00000225528.3',
#  'ENSG00000213699.8',
#  'ENSG00000111897.6',
#  'ENSG00000165650.11',
#  'ENSG00000104381.12',
#  'ENSG00000135413.8',
#  'ENSG00000284844.1',
#  'ENSG00000170881.4',
#  'ENSG00000172037.13',
#  'ENSG00000237643.1',
#  'ENSG00000111181.12',
#  'ENSG00000090273.13',
#  'ENSG00000139620.12',
#  'ENSG00000155367.15',
#  'ENSG00000222028.3',
#  'ENSG00000244607.6',
#  'ENSG00000068903.19',
#  'ENSG00000285473.1',
#  'ENSG00000269028.3',
#  'ENSG00000203814.6',
#  'ENSG00000107077.18',
#  'ENSG00000118242.15',
#  'ENSG00000109736.14',
#  'ENSG00000159231.5',
#  'ENSG00000131116.11',
#  'ENSG00000175262.14',
#  'ENSG00000145198.14',
#  'ENSG00000220205.8',
#  'ENSG00000103174.12',
#  'ENSG00000255284.1',
#  'ENSG00000004799.7',
#  'ENSG00000135018.13',
#  'ENSG00000161281.10',
#  'ENSG00000225413.2',
#  'ENSG00000245750.8',
#  'ENSG00000134308.13',
#  'ENSG00000250855.1',
#  'ENSG00000111834.12',
#  'ENSG00000141200.7',
#  'ENSG00000129559.12',
#  'ENSG00000088986.10',
#  'ENSG00000091140.13',
#  'ENSG00000285971.1',
#  'ENSG00000205642.9',
#  'ENSG00000125816.4',
#  'ENSG00000185863.7',
#  'ENSG00000205884.2',
#  'ENSG00000115295.19',
#  'ENSG00000105669.13',
#  'ENSG00000078804.12',
#  'ENSG00000141448.8',
#  'ENSG00000261466.2',
#  'ENSG00000182450.12',
#  'ENSG00000166448.14',
#  'ENSG00000197444.9',
#  'ENSG00000119596.17',
#  'ENSG00000170255.7',
#  'ENSG00000270035.1',
#  'ENSG00000198055.10',
#  'ENSG00000283952.1',
#  'ENSG00000236384.7',
#  'ENSG00000211966.2',
#  'ENSG00000285040.1',
#  'ENSG00000114383.9',
#  'ENSG00000242736.1',
#  'ENSG00000278129.1',
#  'ENSG00000269895.1',
#  'ENSG00000185985.9',
#  'ENSG00000248187.1',
#  'ENSG00000269391.1',
#  'ENSG00000007255.10',
#  'ENSG00000255992.1',
#  'ENSG00000106278.11',
#  'ENSG00000167191.11',
#  'ENSG00000114126.17',
#  'ENSG00000092094.10',
#  'ENSG00000227869.1',
#  'ENSG00000243444.7',
#  'ENSG00000116819.7',
#  'ENSG00000139405.15',
#  'ENSG00000134042.12',
#  'ENSG00000120539.14',
#  'ENSG00000181649.6',
#  'ENSG00000242622.1',
#  'ENSG00000157353.16',
#  'ENSG00000039600.10',
#  'ENSG00000223870.1',
#  'ENSG00000174106.2',
#  'ENSG00000242009.1',
#  'ENSG00000282012.1',
#  'ENSG00000089847.12',
#  'ENSG00000101180.15',
#  'ENSG00000214039.8',
#  'ENSG00000185640.5',
#  'ENSG00000083312.17',
#  'ENSG00000138029.13',
#  'ENSG00000176231.2',
#  'ENSG00000188828.11',
#  'ENSG00000168495.12',
#  'ENSG00000087448.10',
#  'ENSG00000225697.12',
#  'ENSG00000274776.1',
#  'ENSG00000267712.5',
#  'ENSG00000132746.14',
#  'ENSG00000211644.3',
#  'ENSG00000283217.1',
#  'ENSG00000092377.13',
#  'ENSG00000262772.1',
#  'ENSG00000124380.10',
#  'ENSG00000136939.1',
#  'ENSG00000151632.17',
#  'ENSG00000173660.11',
#  'ENSG00000180739.13',
#  'ENSG00000156475.18',
#  'ENSG00000136487.17',
#  'ENSG00000261611.6',
#  'ENSG00000085117.11',
#  'ENSG00000273476.1',
#  'ENSG00000115488.3',
#  'ENSG00000264964.1',
#  'ENSG00000204277.1',
#  'ENSG00000269966.1',
#  'ENSG00000184471.7',
#  'ENSG00000137821.11',
#  'ENSG00000258497.1',
#  'ENSG00000141452.9',
#  'ENSG00000183862.5',
#  'ENSG00000182158.14',
#  'ENSG00000245832.6',
#  'ENSG00000171714.11',
#  'ENSG00000197079.8',
#  'ENSG00000273559.4',
#  'ENSG00000086712.12',
#  'ENSG00000231678.2',
#  'ENSG00000140598.14',
#  'ENSG00000205707.10',
#  'ENSG00000138738.10',
#  'ENSG00000254039.1',
#  'ENSG00000196811.11',
#  'ENSG00000243089.1',
#  'ENSG00000259334.1',
#  'ENSG00000170381.13',
#  'ENSG00000182095.14',
#  'ENSG00000242110.7',
#  'ENSG00000274469.1',
#  'ENSG00000249265.1',
#  'ENSG00000284762.1',
#  'ENSG00000254258.1',
#  'ENSG00000131686.14',
#  'ENSG00000242221.8',
#  'ENSG00000250567.1',
#  'ENSG00000102924.11',
#  'ENSG00000101079.20',
#  'ENSG00000231505.1',
#  'ENSG00000163938.16',
#  'ENSG00000107331.16',
#  'ENSG00000273098.2',
#  'ENSG00000136856.17',
#  'ENSG00000075568.16',
#  'ENSG00000142156.14',
#  'ENSG00000125772.12',
#  'ENSG00000049167.14',
#  'ENSG00000061337.15',
#  'ENSG00000265690.7',
#  'ENSG00000075539.14',
#  'ENSG00000121454.5',
#  'ENSG00000167775.10',
#  'ENSG00000132692.18',
#  'ENSG00000105374.9',
#  'ENSG00000237700.2',
#  'ENSG00000214338.10',
#  'ENSG00000234880.1',
#  'ENSG00000197893.13',
#  'ENSG00000102934.9',
#  'ENSG00000263594.1',
#  'ENSG00000152760.9',
#  'ENSG00000070018.8',
#  'ENSG00000251616.1',
#  'ENSG00000131538.7',
#  'ENSG00000274576.2',
#  'ENSG00000115816.14',
#  'ENSG00000255823.4',
#  'ENSG00000140263.13',
#  'ENSG00000169223.14',
#  'ENSG00000264112.1',
#  'ENSG00000065923.9',
#  'ENSG00000145681.10',
#  'ENSG00000214894.6',
#  'ENSG00000211896.7',
#  'ENSG00000256152.2',
#  'ENSG00000213714.1',
#  'ENSG00000170382.11',
#  'ENSG00000118922.17',
#  'ENSG00000174444.14',
#  'ENSG00000257065.1',
#  'ENSG00000214293.8',
#  'ENSG00000270316.1',
#  'ENSG00000211876.1',
#  'ENSG00000159496.14',
#  'ENSG00000211691.2',
#  'ENSG00000280366.1',
#  'ENSG00000204887.4',
#  'ENSG00000129515.18',
#  'ENSG00000280018.3',
#  'ENSG00000236437.1',
#  'ENSG00000233605.2',
#  'ENSG00000248125.1',
#  'ENSG00000198040.10',
#  'ENSG00000163536.12',
#  'ENSG00000213190.3',
#  'ENSG00000151812.14',
#  'ENSG00000255983.1',
#  'ENSG00000203972.9',
#  'ENSG00000248215.5',
#  'ENSG00000255247.1',
#  'ENSG00000169826.7',
#  'ENSG00000179580.9',
#  'ENSG00000271709.1',
#  'ENSG00000269155.2',
#  'ENSG00000197210.7',
#  'ENSG00000170035.15',
#  'ENSG00000160539.5',
#  'ENSG00000113273.16',
#  'ENSG00000168280.16',
#  'ENSG00000100490.9',
#  'ENSG00000129103.17',
#  'ENSG00000174016.11',
#  'ENSG00000249811.2',
#  'ENSG00000151502.10',
#  'ENSG00000162910.18',
#  'ENSG00000172115.8',
#  'ENSG00000241180.1',
#  'ENSG00000089597.17',
#  'ENSG00000132704.15',
#  'ENSG00000272915.1',
#  'ENSG00000269186.2',
#  'ENSG00000223501.8',
#  'ENSG00000267535.1',
#  'ENSG00000259240.1',
#  'ENSG00000141293.15',
#  'ENSG00000255039.1',
#  'ENSG00000008118.9',
#  'ENSG00000261715.1',
#  'ENSG00000204092.2',
#  'ENSG00000198231.12',
#  'ENSG00000237292.1',
#  'ENSG00000284018.1',
#  'ENSG00000234396.3',
#  'ENSG00000244067.2',
#  'ENSG00000255135.3',
#  'ENSG00000167748.10',
#  'ENSG00000176563.9',
#  'ENSG00000165462.5',
#  'ENSG00000214216.10',
#  'ENSG00000105835.11',
#  'ENSG00000178188.14',
#  'ENSG00000261749.2',
#  'ENSG00000254788.7',
#  'ENSG00000170477.12',
#  'ENSG00000203809.6',
#  'ENSG00000005022.5',
#  'ENSG00000237513.1',
#  'ENSG00000266094.7',
#  'ENSG00000234056.1',
#  'ENSG00000253857.1',
#  'ENSG00000166664.13',
#  'ENSG00000088930.7',
#  'ENSG00000137802.13',
#  'ENSG00000145063.14',
#  'ENSG00000133773.11',
#  'ENSG00000237531.6',
#  'ENSG00000103196.11',
#  'ENSG00000213638.5',
#  'ENSG00000235070.3',
#  'ENSG00000162552.14',
#  'ENSG00000067646.11',
#  'ENSG00000131951.11',
#  'ENSG00000163528.12',
#  'ENSG00000187546.13',
#  'ENSG00000250969.1',
#  'ENSG00000267385.1',
#  'ENSG00000107796.13',
#  'ENSG00000203837.4',
#  ...}

# %%
long_id = [x for x in desired_genes if x.startswith('ENSG00000267749')]
long_id
# Out:
# []

# %%
filtered_parser.gtf[filtered_parser.gtf['gene_id'] == 'ENSG00000259588.1'][['gene_id', 'gene_type', 'transcript_type']]
# Out:
# Empty DataFrame
# Columns: [gene_id, gene_type, transcript_type]
# Index: []
